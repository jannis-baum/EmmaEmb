# %% [markdown]
# <a href="https://colab.research.google.com/github/pia-francesca/ema/blob/main/examples/Pla2g2/emmaemb_pla2g2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EmmaEmb: Comparative Analysis of Embedding Spaces
#
# Welcome to the example Colab notebook for EmmaEmb, a Python library for analyzing and comparing embedding spaces in molecular biology. EmmaEmb provides tools to explore how different embedding models capture biological information, enabling insights into feature similarities, differences, and relationships across embeddings.
#
# Link to GitHub: https://github.com/broadinstitute/EmmaEmb
#
#
# ### Notebook content
#
# This notebook demonstrates key functionalities of EmmaEmb, including:
#
# 1. [Initialising the Emma object](#section-one)
#
# 2. [Adding embedding spaces](#section-two)
#
# 3. [Feature distribution across spaces](#section-three)
#
# 4. [Pairwise space comparison](#section-four)
#
# ![EmmaEmb Overview](https://raw.githubusercontent.com/broadinstitute/EmmaEmb/main/images/emma_overview.jpg)

# %% [markdown]
# ## 0. Loading dependencies and data
#
# Information of the data and embedding models can be found here: https://github.com/broadinstitute/EmmaEmb/tree/main/examples/Pla2g2

# %%
#@title Install dependencies
# %pip install emmaemb
# Out:
# Collecting emmaemb
#   Downloading emmaemb-1.0.3-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: importlib-metadata>=8.5.0 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (8.6.1)
# Requirement already satisfied: joblib>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (1.4.2)
# Requirement already satisfied: llvmlite>=0.41.1 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (0.44.0)
# Requirement already satisfied: narwhals>=1.24.1 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (1.25.1)
# Requirement already satisfied: numba>=0.58.1 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (0.61.0)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (1.26.4)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (24.2)
# Requirement already satisfied: pandas>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (2.2.2)
# Requirement already satisfied: patsy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (1.0.1)
# Collecting plotly-express>=0.4.1 (from emmaemb)
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting plotly>=6.0.0 (from emmaemb)
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pynndescent>=0.5.13 (from emmaemb)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Collecting python-dateutil>=2.9.0.post0 (from emmaemb)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: pytz>=2024.2 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (2025.1)
# Requirement already satisfied: scikit-learn>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (1.6.1)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (1.13.1)
# Requirement already satisfied: six>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (1.17.0)
# Requirement already satisfied: statsmodels>=0.14.1 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (0.14.4)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (3.5.0)
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (4.67.1)
# Requirement already satisfied: tzdata>=2025.1 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (2025.1)
# Collecting umap-learn>=0.5.7 (from emmaemb)
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: zipp>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from emmaemb) (3.21.0)
# Downloading emmaemb-1.0.3-py3-none-any.whl (16 kB)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 35.0 MB/s eta 0:00:00
# Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 3.0 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 11.0 MB/s eta 0:00:00
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: python-dateutil, plotly, pynndescent, umap-learn, plotly-express, emmaemb
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# Successfully installed emmaemb-1.0.3 plotly-6.0.0 plotly-express-0.4.1 pynndescent-0.5.13 python-dateutil-2.9.0.post0 umap-learn-0.5.7

# %%
#@title Download example data from EmmaEmb repository

import requests
import pandas as pd
import os

# download embeddings

models = ["ESMC", "ProtT5"]
embedding_url_dir = "https://raw.githubusercontent.com/broadinstitute/EmmaEmb/main/examples/Pla2g2/embeddings/"

headers = {"User-Agent": "Mozilla/5.0"}
csv_url = "https://raw.githubusercontent.com/broadinstitute/EmmaEmb/main/examples/Pla2g2/Pla2g2_features.csv"

csv_filename = "Pla2g2_features.csv"
csv_response = requests.get(csv_url, headers=headers)
if csv_response.status_code == 200:
    with open(csv_filename, "wb") as f:
        f.write(csv_response.content)
else:
    print(f"Failed to download {csv_filename}")


df_pla2g2 = pd.read_csv(csv_filename)
proteins = df_pla2g2['identifier'].values

# now for each model download embedding files for each protein
for model in models:
  model_dir = f"embeddings/{model}"
  os.makedirs(model_dir, exist_ok=True)

  for protein in proteins:
    file_path = os.path.join(model_dir, f"{protein}.npy")

    # Check if file already exists
    if os.path.exists(file_path):
        continue

    url = f"{embedding_url_dir}{model}/{protein}.npy"
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
      # store in embeddings/model/protein-id.npy
      with open("embeddings/" + model + "/" + protein + ".npy", "wb") as f:
        f.write(response.content)
    else:
      print(f"Failed to download {url}")


print("All download of feature data complete.")
# Out:
# All download of feature data complete.

# %% [markdown]
# <a name="section-one"></a>
# ## 1. Initialising the Emma object

# %%
import pandas as pd
from emmaemb import Emma

# %% [markdown]
# ### Feature data table

# %% [markdown]
# Loading feature data. The first column includes the identifiers of the samples, in this case proteins. The remaining columns contain meta data on each sample.

# %%
df_pla2f2 = pd.read_csv("Pla2g2_features.csv")
print(df_pla2f2.shape)
df_pla2f2.head()
# Out:
# (446, 7)
#   identifier      gene      group enzyme_class  species  seq_length length_bin
# 0     mAimeC   Pla2g2C  C mammals            C  mammals         132    130-135
# 1     mAimeF   Pla2g2F  F mammals            F  mammals         136    135-145
# 2    mAimeDb  Pla2g2D1  D mammals            D  mammals         124    120-130
# 3    mAimeDa  Pla2g2D1  D mammals            D  mammals         124    120-130
# 4     mAimeE   Pla2g2E  E mammals            E  mammals         123    120-130

# %% [markdown]
# Initialising Emma object with the feature data in format of a pandas df. The datatype stored in each column of the feature data is detected. Only cateorical data will be available for downstream analysis with the Emma library.
#
# Note: Quantitative features can be binned to allow analysis with EmmaEmb.

# %%
# initiate Emma object with the metadata

emma = Emma(df_pla2f2)
# Out:
# 446 samples loaded.
# Categories in meta data: ['gene', 'group', 'enzyme_class', 'species', 'length_bin']
# Numerical columns in meta data: ['seq_length']

# %% [markdown]
# <a name="section-two"></a>
# ## 2. Adding embedding spaces

# %% [markdown]
# Adding embedding spaces. Embedding spaces can be added one by one. Either by
#
# - providing a link to a directory which stores the embeddings in individual files with the identifiers from the feature table or
#
# - by providing a numpy array which includes the embeddings in each row and in the same order as in the feature data table.
#
#
# Multiple embedding spaces can be added. Dimensions of the embeddings do not have to be the same across embedding spaces. Embedding spaces can be removed using the `remove_emb_space(emb_space_name: str)` function.

# %%
embedding_dir = "embeddings/"
models = ["ProtT5", "ESMC"]

# %%
for model_name in models:
    emma.load_emb_space_from_disk(
        embeddings_source=embedding_dir + model_name,
        emb_space_name=model_name,
    )
# Out:
# Embedding space 'ProtT5' added successfully.
# Embeddings have 1024 features each.
# Embedding space 'ESMC' added successfully.
# Embeddings have 960 features each.

# %% [markdown]
# ### Visualization of embedding spaces using dimensionality reduction techniques
#
# The `plot_emb_space` function visualizes the embeddings of a specified embedding space in 2D using dimensionality reduction techniques such as PCA, t-SNE, or UMAP. It takes an Emma instance containing multiple embedding spaces and projects the selected space into two dimensions, optionally normalizing the data beforehand. The resulting scatter plot can be colored based on metadata attributes, allowing for an intuitive exploration of patterns within the embedding space.

# %%
# visualise reduced embedding space
from emmaemb.vizualization import plot_emb_space

fig_pca = plot_emb_space(emma=emma,
                         emb_space="ProtT5",
                         method="PCA",
                         color_by="enzyme_class",
                         normalise=True)
fig_pca.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="533ab3d5-1e73-470e-90e7-b0e130ba1a35" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("533ab3d5-1e73-470e-90e7-b0e130ba1a35")) {                    Plotly.newPlot(                        "533ab3d5-1e73-470e-90e7-b0e130ba1a35",                        [{"customdata":[["mAimeC"],["mAifuC"],["cAlmiC"],["cAlsiC"],["bAnplC"],["bAncyC"],["bApfoC"],["bApauC"],["bAqchC"],["bBareC"],["mBibiC"],["mBotaC"],["mCaluC"],["mCahiC"],["mChlaC"],["bChmaC"],["cCrpoC"],["bCucaC"],["mDanoC"],["mEnluC"],["mEqcaC"],["mEreuC"],["bGagaC"],["cGavganC"],["bHaleC"],["mLoafC"],["mMimuC"],["mModoC"],["mMumuC"],["mMupuC"],["mMyluC"],["bNaauC"],["mOcprC"],["mOdviC"],["bOphoC"],["mOrorC"],["mOrcuC"],["mOvarC"],["mPatiC"],["mPahoC"],["bPafaC"],["mPhciC"],["bPskrC"],["mPtvaC"],["bPyadC"],["mSahaC"],["mSoarC"],["bStocC"],["mTrmaC"],["bUrpeC"],["mUrmaC"]],"hovertemplate":"enzyme_class=C\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eSample=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"C","marker":{"color":"rgb(102,194,165)","opacity":0.5,"symbol":"circle","size":10},"mode":"markers","name":"C","orientation":"v","showlegend":true,"x":{"dtype":"f4","bdata":"6rPfwLVN3sA+hdhAkuDFQOCwnEBBC4VAeMaUQJjQ9T825TxAjjt3QKR3vsAS4rrAe6jXwFlbrcBFw5HAAflJOxEMpUAV8YdAGDrTwNlrzMAgSpTAuOAcwZBUgD5WzMtAYl8WQM+XssCgoHTA+N0PQC5ngcCKRcbAq6CmwOI6pECuP+rAn7CTwGaQqUBegYXBYWQFwWdPu8CfT7\u002fAtmmxwEsxXb+YL4w\u002fwP0HQCjXgcD+DnNAX6yJv6zktMAA2o5AMwHEwI74s0DKHuHA"},"xaxis":"x","y":{"dtype":"f4","bdata":"JGgUQCdL2EBWcqnBrLSLwRIVIL\u002fAVAi+jXOIwHgdb8D4mAlAA31Vvw2D4ECdZNdAyJVMQL0CuECtTRtA4Ql7QMZ3qsHzyWDAQubWP9YCvUCdZzdAjsdVQfERh0DJDbzBP5dVQFuuQ78oeT7ANsvJwCXPAEC3PKFAZfyzQFhb1b\u002fNN\u002fxAtF\u002fTQCVaBsBUPm8\u002fY7rVQN8yzkDIHp9AVZ3bQLlKGkEDGi\u002fAdbvbQDQXLb9zv8K\u002fk2RBPrSBnUDDO7K\u002f9O0ZQFNrDMDa7ylA"},"yaxis":"y","type":"scatter"},{"customdata":[["mAimeF"],["mAifuF"],["mBibiF"],["sBocoF"],["mBotaF"],["mCaluF"],["mCahiF"],["cChmyF"],["mChlaF"],["cChpiF"],["mCocrF"],["sCradF"],["sCratF"],["sCrheAF"],["sCrheBF"],["sCrhoAF"],["sCrhoBF"],["sCrscAF"],["sCrscBF"],["mDanoF"],["sDeacF"],["mEledF"],["mEnluF"],["mEqcaF"],["mEreuF"],["mFecaF"],["cGoagF"],["mHeglF"],["mHosaF"],["sLabiF"],["sLaviF"],["mLoafF"],["mMamaF"],["mMimuF"],["mModoF"],["mMumuF"],["mMupuF"],["mMyluF"],["mNescF"],["sNoscF"],["mOcprF"],["mOdviF"],["sOphaF"],["sOpgrF"],["mOranF"],["mOrcuF"],["mOvarF"],["mPatiF"],["mPahoF"],["sPapiF"],["cPesiF"],["mPhciF"],["sPoviF"],["sPrmuF"],["sPsteF"],["mPtvaF"],["sPybiF"],["mSahaF"],["mSoarF"],["mTrmaF"],["sVibeF"]],"hovertemplate":"enzyme_class=F\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eSample=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"rgb(252,141,98)","opacity":0.5,"symbol":"circle","size":10},"mode":"markers","name":"F","orientation":"v","showlegend":true,"x":{"dtype":"f4","bdata":"b77zv2oi2MAmB+s\u002fHe\u002fwv4X4xz1Nk6HA8Z4dwHkFJEB1utnAZmk7QE\u002fh1sAYy46\u002f7EaQv+xGkL+WKBm\u002fA8s2PgPLNj6WKBm\u002fligZv4p1OMG3Cai\u002fxk1SwPneycCJ+c\u002fAhAsSwZVNs8AUhmZA2A26wKjhwsD8hC9A\u002fIQvQG6I18CUF4TA+LvgwGhMEMDeH07AWKa\u002fwNC4msACxvHARhIfPySXiMAsRpy\u002f0Mqfvkg9LsHdLqPAca1wwNMI17+g4BbBHwlgvWe3ScHWDWFAoXAvwNSrK8Fddry\u002fOC47PxEalcASrM2\u002frW15wFpAXcByRAPBTt9VwA=="},"xaxis":"x","y":{"dtype":"f4","bdata":"ieSrQeQOzEFllnBBGMriQGSslkFKncBBpSm2Qfo3rMB5Y7RBTa27v13ix0E7yIpAe71SQHu9UkB\u002fq1xAlCIRQJQiEUB\u002fq1xAf6tcQIZi+EG8y99AiSyvQdH53EHlGMdBXYboQRoPxUGQ5jbAEOaaQeYdvUFLo1rAS6NawJj3uUGZKL1B3Ei+QdtnkUFmiI5Ba9TaQYwMqEHQw95BLtxyQL1VwEENfZRBFQELPzAZakEi9qJBrb2wQSeBrUGXG89BK9qXQXgKyEEW77u\u002fpg+sQZJCLEFPE9RAl9CSPzgFqUHCyK4\u002fZuWnQQUVuUG79qdBD5WMQA=="},"yaxis":"y","type":"scatter"},{"customdata":[["mAimeDb"] ...

# %% [markdown]
# <a name="section-three"></a>
# ## 3. Feature distribution across spaces

# %% [markdown]
# The `get_pairwise_distances` function of the Emma object calculates pairwise distances between samples within a specified embedding space using a chosen distance metric. Implemented distance metrics, include Euclidean, Manhattan, Cosine, and Mahalanobis distances, among scaled versions. To improve efficiency, the function checks if the distances have already been computed and stored in the Emma object, avoiding redundant calculations.

# %%
pwd = emma.get_pairwise_distances("ProtT5", "cityblock")
pwd = emma.get_pairwise_distances("ESMC", "cityblock")
# Out:
# Calculating pairwise distances using cityblock...
# Calculating pairwise distances using cityblock...

# %% [markdown]
# #### 3.1 KNN feature alignment scores

# %% [markdown]
# The `plot_knn_alignment_across_embedding_spaces` function visualizes k-nearest neighbor (KNN) feature alignment scores for a specified feature across multiple embedding spaces.
# It computes what fraction of the KNN embeddings are labelled with the same label for the selected feature.
# The scores are calculated for each embedding in each embedding space.
# Pairwise distances need to be pre-computed for each embedding space and each distance metric using the `get_pairwise_distances` function (see code block above).
# The function produces a box plot and allows customization of the embedding space order and plot color.

# %%
# KNN ALIGNMENT SCORES
from emmaemb.vizualization import plot_knn_alignment_across_embedding_spaces

fig_alignment_scores = plot_knn_alignment_across_embedding_spaces(
    emma, feature="enzyme_class", k=10, metric="cityblock"
)
fig_alignment_scores.update_layout(height=600, width=500)
fig_alignment_scores.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="aa556caa-e45c-404a-842e-aa5c522b20ff" class="plotly-graph-div" style="height:600px; width:500px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("aa556caa-e45c-404a-842e-aa5c522b20ff")) {                    Plotly.newPlot(                        "aa556caa-e45c-404a-842e-aa5c522b20ff",                        [{"alignmentgroup":"True","hovertemplate":"Embedding Space=%{x}\u003cbr\u003eKNN feature alignment scores=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#303496"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5","ProtT5"," ...

# %% [markdown]
# The KNN feature alignment scores can also be aggregated. The `plot_knn_alignment_across_classes` shows a heatmap of the mean value of the KNN feature alignment scores stratified by embedding space and feature class.

# %%
from emmaemb.vizualization import plot_knn_alignment_across_classes

fig_alignment_scores_class = plot_knn_alignment_across_classes(
    emma, feature="enzyme_class", k=100, metric="cityblock"
)
fig_alignment_scores_class.update_layout(height=600, width=500)
fig_alignment_scores_class.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="6852918a-1118-4ed0-b47e-620d2ef9661e" class="plotly-graph-div" style="height:600px; width:500px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6852918a-1118-4ed0-b47e-620d2ef9661e")) {                    Plotly.newPlot(                        "6852918a-1118-4ed0-b47e-620d2ef9661e",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z:.2f}","x":["ESMC","ProtT5"],"y":["A (n = 65)","B (n = 15)","C (n = 51)","D (n = 73)","D1 (n = 7)","D2 (n = 3)","D3 (n = 8)","E (n = 70)","F (n = 61)","G (n = 53)","V (n = 40)"],"z":{"dtype":"f8","bdata":"Y2zQ3YB+1T+5TME9OBPWP+xRuB6F68E\u002fGQRWDi2yvT+qQ912EKrTP8EnjvRawdc\u002fP\u002foIwMdw3D8toSPCmN\u002fWP7gehetRuK4\u002fHdRBHdRBrT97FK5H4XqUP3sUrkfhepQ\u002f7FG4HoXrsT+kcD0K16OwP3AGPoS0hdU\u002fhMDKoUW22z+62dOKkQnbP0UOH8tuPNg\u002fsgj\u002fON0D3D9\u002fQYHPxsfeP2Dl0CLb+c4\u002f1qNwPQrXzz8=","shape":"11, 2"},"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Embedding Space: %{x}\u003cbr\u003eFeature Class (Samples): %{y}\u003cbr\u003eMean KNN feature alignment score: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlin ...

# %% [markdown]
# ### 3.2 KNN class mixing matrix

# %% [markdown]
# The KNN class mixing matrix quantifies the mixing of classes within the KNN neighborhood of samples in a given embedding space.
# Given a distance metric (default: euclidean), the KNN are retrieved for each sample and the KNN class `get_class_mixing_in_neighborhood` counts how often different classes appear among its neighbors. The function returns a class mixing matrix, where each entry represents the number of times a class appears in the neighborhood of another class, along with the unique class labels. The heatmap can be visualised using the `plot_knn_class_mixing_matrix` function.

# %%
# KNN CLASS MIXING MATRIX
from emmaemb.vizualization import plot_knn_class_mixing_matrix

fig_class_mixing_matrix = plot_knn_class_mixing_matrix(
    emma,
    emb_space="ProtT5",
    feature="enzyme_class",
    k=100,
    metric="cityblock",
)
fig_class_mixing_matrix.update_layout(height=600, width=600)
fig_class_mixing_matrix.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="df01d962-7ab9-481e-a740-459a658b6f8a" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("df01d962-7ab9-481e-a740-459a658b6f8a")) {                    Plotly.newPlot(                        "df01d962-7ab9-481e-a740-459a658b6f8a",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z:.0f}","x":["A","B","C","D","D1","D2","D3","E","F","G","V"],"y":["A","B","C","D","D1","D2","D3","E","F","G","V"],"z":{"dtype":"i2","bdata":"","shape":"11, 11"},"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Feature Class (Sample): %{x}\u003cbr\u003eFeature Class (Neighbor): %{y}\u003cbr\u003eNeighbor Count: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[ ...

# %% [markdown]
# <a name="section-four"></a>
# ## 4. Pairwise space comparison

# %% [markdown]
# ### 4.1 Global comparison of pairwise distances

# %% [markdown]
# The `plot_pairwise_distance_comparison` function generates a scatter plot to compare pairwise distances between samples in two different embedding spaces. Using a specified distance metric (default: euclidean), it shows the distances for the same set of samples across both embedding spaces.
# Additionally it computes the Spearman correlation coefficient between the pairwise distances in the two selected embedding spaces.
# The function allows customization of plot title, color, and scatter dot opacity, and optionally groups points based on a meta data feature, enabling insights into how different sample categories behave across embeddings.

# %%
from emmaemb.vizualization import plot_pairwise_distance_comparison

fig_pwd_comparison = plot_pairwise_distance_comparison(
    emma,
    emb_space_y="ProtT5",
    emb_space_x="ESMC",
    metric="cityblock",
    group_by="species",
)
fig_pwd_comparison.update_layout(height=600, width=600)
fig_pwd_comparison.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="35b650ba-41cb-4664-b867-cfe10f3a5484" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("35b650ba-41cb-4664-b867-cfe10f3a5484")) {                    Plotly.newPlot(                        "35b650ba-41cb-4664-b867-cfe10f3a5484",                        [{"customdata":[["mAimeC - mAimeF"],["mAimeC - mAimeDb"],["mAimeC - mAimeDa"],["mAimeC - mAimeE"],["mAimeC - mAifuE"],["mAimeC - mAifuV"],["mAimeC - mAifuD"],["mAimeC - mAifuF"],["mAimeC - mAifuC"],["mAimeC - mBibiE"],["mAimeC - mBibiA2"],["mAimeC - mBibiA3"],["mAimeC - mBibiA4"],["mAimeC - mBibiDa"],["mAimeC - mBibiDb"],["mAimeC - mBibiF"],["mAimeC - mBibiC"],["mAimeC - mBotaC"],["mAimeC - mBotaF"],["mAimeC - mBotaDb"],["mAimeC - mBotaDa"],["mAimeC - mBotaV"],["mAimeC - mBotaA5"],["mAimeC - mBotaA3"],["mAimeC - mBotaA"],["mAimeC - mCaluC"],["mAimeC - mCaluF"],["mAimeC - mCaluD1"],["mAimeC - mCaluV"],["mAimeC - mCaluE"],["mAimeC - mCahiE"],["mAimeC - mCahiA"],["mAimeC - mCahiA2"],["mAimeC - mCahiA4"],["mAimeC - mCahiA5"],["mAimeC - mCahiV"],["mAimeC - mCahiDa"],["mAimeC - mCahiDb"],["mAimeC - mCahiF"],["mAimeC - mCahiC"],["mAimeC - mChlaE"],["mAimeC - mChlaA2"],["mAimeC - mChlaA3"],["mAimeC - mChlaA4"],["mAimeC - mChlaV"],["mAimeC - mChlaD"],["mAimeC - mChlaF"],["mAimeC - mChlaC"],["mAimeC - mCocrE"],["mAimeC - mCocrA2"],["mAimeC - mCocrA3"],["mAimeC - mCocrV"],["mAimeC - mCocrD"],["mAimeC - mCocrF"],["mAimeC - mDanoA"],["mAimeC - mDanoV"],["mAimeC - mDanoD"],["mAimeC - mDanoF"],["mAimeC - mDanoC"],["mAimeC - mEledF"],["mAimeC - mEledD1"],["mAimeC - mEledV"],["mAimeC - mEledA3"],["mAimeC - mEledA2"],["mAimeC - mEledA1"],["mAimeC - mEledE"],["mAimeC - mEnluC"],["mAimeC - mEnluF"],["mAimeC - mEnluD1"],["mAimeC - mEnluV"],["mAimeC - mEnluE"],["mAimeC - mEqcaC"],["mAimeC - mEqcaF"],["mAimeC - mEqcaD"],["mAimeC - mEqcaV"],["mAimeC - mEqcaA"],["mAimeC - mEqcaE"],["mAimeC - mEreuC"],["mAimeC - mEreuF"],["mAimeC - mEreuD1"],["mAimeC - mEreuV"],["mAimeC - mEreuA15"],["mAimeC - mEreuA14"],["mAimeC - mEreuA13"],["mAimeC - mEreuA12"],["mAimeC - mEreuA11"],["mAimeC - mEreuA10"],["mAimeC - mEreuA9"],["mAimeC - mEreuA8"],["mAimeC - mEreuA7"],["mAimeC - mEreuA6"],["mAimeC - mEreuA5"],["mAimeC - mEreuA3"],["mAimeC - mEreuA2"],["mAimeC - mEreuA1"],["mAimeC - mEreuE"],["mAimeC - mFecaE"],["mAimeC - mFecaV"],["mAimeC - mFecaD"],["mAimeC - mFecaF"],["mAimeC - mHeglE"],["mAimeC - mHeglA1"],["mAimeC - mHeglA2"],["mAimeC - mHeglA3"],["mAimeC - mHeglV"],["mAimeC - mHeglD"],["mAimeC - mHeglF"],["mAimeC - mHosaE"],["mAimeC - mHosaA"],["mAimeC - mHosaV"],["mAimeC - mHosaD"],["mAimeC - mHosaF"],["mAimeC - mLoafC"],["mAimeC - mLoafF"],["mAimeC - mLoafD"],["mAimeC - mLoafV"],["mAimeC - mLoafA2"],["mAimeC - mLoafA1"],["mAimeC - mLoafE"],["mAimeC - mMamaF"],["mAimeC - mMamaD"],["mAimeC - mMamaV"],["mAimeC - mMamaA1"],["mAimeC - mMamaE"],["mAimeC - mMimuE"],["mAimeC - mMimuA"],["mAimeC - mMimuV"],["mAimeC - mMimuD"],["mAimeC - mMimuF"],["mAimeC - mMimuC"],["mAimeC - mModoC"],["mAimeC - mModoF"],["mAimeC - mModoD"],["mAimeC - mModoV2"],["mAimeC - mModoV1"],["mAimeC - mModoE"],["mAimeC - mMumuC"],["mAimeC - mMumuF"],["mAimeC - mMumuD1"],["mAimeC - mMumuV1"],["mAimeC - mMumuA"],["mAimeC - mMumuE"],["mAimeC - mMupuC"],["mAimeC - mMupuF"],["mAimeC - mMupuD"],["mAimeC - mMupuV"],["mAimeC - mMupuE"],["mAimeC - mMyluE"],["mAimeC - mMyluA1"],["mAimeC - mMyluA2"],["mAimeC - mMyluA4"],["mAimeC - mMyluV"],["mAimeC - mMyluD"],["mAimeC - mMyluF"],["mAimeC - mMyluC"],["mAimeC - mNescE"],["mAimeC - mNescV"],["mAimeC - mNescD"],["mAimeC - mNescF"],["mAimeC - mOcprC"],["mAimeC - mOcprF"],["mAimeC - mOcprD"],["mAimeC - mOcprV"],["mAimeC - mOcprA3"],["mAimeC - mOcprA2"],["mAimeC - mOcprA1"],["mAimeC - mOcprE"],["mAimeC - mOdviC"],["mAimeC - mOdviF"],[ ...

# %% [markdown]
# ### 4.2 Cross- space neighborhood similarity

# %% [markdown]
# The `plot_low_similarity_distribution` function visualizes the class distribution of samples with low neighborhood similarity between two embedding spaces. It computes neighborhood similarity scores based on a specified distance metric (default: euclidean) and identifies samples where similarity of the nearest neighbors of a data point falls below a given threshold. The function then compares the class distribution of these low-similarity samples to the overall dataset distribution using a scatter plot. This helps assess whether certain classes exhibit higher or lower structural consistency across embeddings, providing insights into differences in how embeddings capture relationships between samples.

# %%
from emmaemb.vizualization import plot_low_similarity_distribution

fig_low_similarity_class_distribution = plot_low_similarity_distribution(
    emma,
    emb_space_1="ProtT5",
    emb_space_2="ESMC",
    feature="enzyme_class",
    k=10,
    metric="cityblock",
    similarity_threshold=0.3,
)
fig_low_similarity_class_distribution.update_layout(height=600, width=600)
fig_low_similarity_class_distribution.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="dbd6c4f3-7bec-4ade-8940-b2287e7a9663" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("dbd6c4f3-7bec-4ade-8940-b2287e7a9663")) {                    Plotly.newPlot(                        "dbd6c4f3-7bec-4ade-8940-b2287e7a9663",                        [{"hovertemplate":"enzyme_class=A\u003cbr\u003eFraction in Dataset=%{x}\u003cbr\u003eFraction in Subsample=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"A","marker":{"color":"#636efa","symbol":"circle","line":{},"size":10},"mode":"markers","name":"A","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"PZVC+pqnwj8="},"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzM3D8="},"yaxis":"y","type":"scatter"},{"hovertemplate":"enzyme_class=B\u003cbr\u003eFraction in Dataset=%{x}\u003cbr\u003eFraction in Subsample=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"B","marker":{"color":"#EF553B","symbol":"circle","line":{},"size":10},"mode":"markers","name":"B","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"wol4SUA4oT8="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAAA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"enzyme_class=C\u003cbr\u003eFraction in Dataset=%{x}\u003cbr\u003eFraction in Subsample=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"C","marker":{"color":"#00cc96","symbol":"circle","line":{},"size":10},"mode":"markers","name":"C","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"MOpM4wZGvT8="},"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZqT8="},"yaxis":"y","type":"scatter"},{"hovertemplate":"enzyme_class=D\u003cbr\u003eFraction in Dataset=%{x}\u003cbr\u003eFraction in Subsample=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"D","marker":{"color":"#ab63fa","symbol":"circle","line":{},"size":10},"mode":"markers","name":"D","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"m6dSSF\u002fzxD8="},"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzwz8="},"yaxis":"y","type":"scatter"},{"hovertemplate":"enzyme_class=D1\u003cbr\u003eFraction in Dataset=%{x}\u003cbr\u003eFraction in Subsample=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"D1","marker":{"color":"#FFA15A","symbol":"circle","line":{},"size":10},"mode":"markers","name":"D1","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"k4BwIl4SkD8="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAAA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"enzyme_class=D2\u003cbr\u003eFraction in Dataset=%{x}\u003cbr\u003eFraction in Subsample=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"D2","marker":{"color":"#19d3f3","symbol":"circle","line":{},"size":10},"mode":"markers","name":"D2","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"atzAqDONez8="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAAA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"enzyme_class=D3\u003cbr\u003eFraction in Dataset=%{x}\u003cbr\u003eFraction in Subsample=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"D3","marker":{"color":"#FF6692","symbol":"circle","line":{},"size":10},"mode":"markers","name":"D3","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"8ZKAcCJekj8="},"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZqT8="},"yaxis":"y","type":"scatter"},{"hovertemplate":"enzyme_class=E\u003cbr\u003eFraction in Dataset=%{x}\u003cbr\u003eFraction in Subsample=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"E","marker":{"color":"#B6E880","symbol":"circle","line":{},"size":10},"mode":"markers","name":"E","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"uKAMq\u002fUWxD8="},"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"yaxis":"y","type":"scatter"},{"hovertemplate":"enzyme_ ...
